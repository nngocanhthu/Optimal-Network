# %%
pip install gurobipy
# Out:
# Requirement already satisfied: gurobipy in /usr/local/lib/python3.10/dist-packages (11.0.2)

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
from math import sqrt
from google.colab import drive
drive.mount("/content/drive")
from google.colab import files
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## **Data Loading**

# %%
def check_dataframe(data):
    datatype = pd.DataFrame(data.dtypes,columns=["Data Type"])
    datatype["Missing Values"]=data.isnull().sum()
    datatype["% Missing Values"]=data.isnull().sum()/len(data)*100
    print(datatype.sort_values(by="% Missing Values", ascending=False).style.background_gradient(cmap='Set3',axis=0).format({'% Missing Values': '{:.2f}%'}))
    return datatype.sort_values(by="% Missing Values", ascending=False).style.background_gradient(cmap='Set3',axis=0).format({'% Missing Values': '{:.2f}%'})

# %%
fcs_df = pd.read_excel("/content/drive/MyDrive/Năm III/SCM/ROUND 2/data/Fulfillment centers.xlsx")
fcs_df.head()
# Out:
#    Location Region Subregion
# 0   TPHCM 1  South       sr1
# 1   TPHCM 2  South       sr1
# 2   TPHCM 3  South       sr1
# 3   TPHCM 4  South       sr1
# 4  Ha Noi 1  North       sr4

# %%
check_dataframe(fcs_df)
# Out:
# <pandas.io.formats.style.Styler object at 0x7c508a170cd0>
# <style type="text/css">
# #T_3e40f_row0_col1, #T_3e40f_row0_col2, #T_3e40f_row1_col1, #T_3e40f_row1_col2, #T_3e40f_row2_col1, #T_3e40f_row2_col2 {
#   background-color: #8dd3c7;
#   color: #000000;
# }
# </style>
# <table id="T_3e40f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e40f_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_3e40f_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#       <th id="T_3e40f_level0_col2" class="col_heading level0 col2" >% Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e40f_level0_row0" class="row_heading level0 row0" >Location</th>
#       <td id="T_3e40f_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_3e40f_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_3e40f_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_3e40f_level0_row1" class="row_heading level0 row1" >Region</th>
#       <td id="T_3e40f_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_3e40f_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_3e40f_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_3e40f_level0_row2" class="row_heading level0 row2" >Subregion</th>
#       <td id="T_3e40f_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_3e40f_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_3e40f_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
subregions = []
for i in range(6):
  subregions.append(f"sr{i}")

# %%
cus_df = pd.read_excel("/content/drive/MyDrive/Năm III/SCM/ROUND 2/data/Customers.xlsx")
cus_df.head()
# Out:
#   Customer Group Region  Demand 2024
# 0        TPHCM 1  South     130372.5
# 1        TPHCM 2  South     130372.5
# 2        TPHCM 3  South     130372.5
# 3        TPHCM 4  South     130372.5
# 4       Ha Noi 1  North     138026.5

# %%
check_dataframe(cus_df)
# Out:
# <pandas.io.formats.style.Styler object at 0x7c508a172650>
# <style type="text/css">
# #T_adc03_row0_col1, #T_adc03_row0_col2, #T_adc03_row1_col1, #T_adc03_row1_col2, #T_adc03_row2_col1, #T_adc03_row2_col2 {
#   background-color: #8dd3c7;
#   color: #000000;
# }
# </style>
# <table id="T_adc03" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_adc03_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_adc03_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#       <th id="T_adc03_level0_col2" class="col_heading level0 col2" >% Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_adc03_level0_row0" class="row_heading level0 row0" >Customer Group</th>
#       <td id="T_adc03_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_adc03_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_adc03_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_adc03_level0_row1" class="row_heading level0 row1" >Region</th>
#       <td id="T_adc03_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_adc03_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_adc03_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_adc03_level0_row2" class="row_heading level0 row2" >Demand 2024</th>
#       <td id="T_adc03_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_adc03_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_adc03_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
weight_list = []
for i in range(23):
  weight_list.append(f'w{i}')
std_demand_df = pd.read_excel("/content/drive/MyDrive/Năm III/SCM/ROUND 2/data/Standard & order distribution.xlsx", sheet_name = 'Standard')
std_demand_df.head()
# Out:
#   Encoded Weight Weight/Zone  % Distribution rate
# 0             w0        0.25             0.335788
# 1             w1         0.5             0.345239
# 2             w2           1             0.191355
# 3             w3         1.5             0.067255
# 4             w4           2             0.017472

# %%
check_dataframe(std_demand_df)
# Out:
# <pandas.io.formats.style.Styler object at 0x7c50ced1a980>
# <style type="text/css">
# #T_314af_row0_col1, #T_314af_row0_col2, #T_314af_row1_col1, #T_314af_row1_col2, #T_314af_row2_col1, #T_314af_row2_col2 {
#   background-color: #8dd3c7;
#   color: #000000;
# }
# </style>
# <table id="T_314af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_314af_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_314af_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#       <th id="T_314af_level0_col2" class="col_heading level0 col2" >% Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_314af_level0_row0" class="row_heading level0 row0" >Encoded Weight</th>
#       <td id="T_314af_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_314af_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_314af_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_314af_level0_row1" class="row_heading level0 row1" >Weight/Zone</th>
#       <td id="T_314af_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_314af_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_314af_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_314af_level0_row2" class="row_heading level0 row2" >% Distribution rate</th>
#       <td id="T_314af_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_314af_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_314af_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
exp_demand_df = pd.read_excel("/content/drive/MyDrive/Năm III/SCM/ROUND 2/data/Standard & order distribution.xlsx", sheet_name = 'Express')
exp_demand_df.head()
# Out:
#   Encoded Weight Weight/Zone  % Distribution rate
# 0             w0        0.25             0.000000
# 1             w1         0.5             0.000000
# 2             w2           1             0.000000
# 3             w3         1.5             0.229185
# 4             w4           2             0.066710

# %%
check_dataframe(exp_demand_df)
# Out:
# <pandas.io.formats.style.Styler object at 0x7c508a14e140>
# <style type="text/css">
# #T_0861b_row0_col1, #T_0861b_row0_col2, #T_0861b_row1_col1, #T_0861b_row1_col2, #T_0861b_row2_col1, #T_0861b_row2_col2 {
#   background-color: #8dd3c7;
#   color: #000000;
# }
# </style>
# <table id="T_0861b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0861b_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_0861b_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#       <th id="T_0861b_level0_col2" class="col_heading level0 col2" >% Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0861b_level0_row0" class="row_heading level0 row0" >Encoded Weight</th>
#       <td id="T_0861b_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_0861b_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0861b_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0861b_level0_row1" class="row_heading level0 row1" >Weight/Zone</th>
#       <td id="T_0861b_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_0861b_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_0861b_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_0861b_level0_row2" class="row_heading level0 row2" >% Distribution rate</th>
#       <td id="T_0861b_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_0861b_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_0861b_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
std_rate_df = pd.read_excel("/content/drive/MyDrive/Năm III/SCM/ROUND 2/data/StdRate.xlsx", sheet_name='Sheet1')
std_rate_df.head()
# Out:
#    Location  Intra city_w0  Intra city_w1  Intra city_w2  Intra city_w3  \
# 0   TPHCM 1        8689.36       10733.92       13085.16       16560.91
# 1   TPHCM 2        8689.36       10733.92       13085.16       16560.91
# 2   TPHCM 3        8689.36       10733.92       13085.16       16560.91
# 3   TPHCM 4        8689.36       10733.92       13085.16       16560.91
# 4  Ha Noi 1        8932.99       11034.87       13452.04       17025.23
#
#    Intra city_w4  Intra city_w5  Intra city_w6  Intra city_w7  Intra city_w8  \
# 0       18912.15       20445.56       22490.12       24534.68       26579.24
# 1       18912.15       20445.56       22490.12       24534.68       26579.24
# 2       18912.15       20445.56       22490.12       24534.68       26579.24
# 3       18912.15       20445.56       22490.12       24534.68       26579.24
# 4       19442.40       21018.81       23120.69       25222.57       27324.45
#
#    ...  North-South_w13  North-South_w14  North-South_w15  North-South_w16  \
# 0  ...        155897.42        166631.34        177365.26        188099.18
# 1  ...        155897.42        166631.34        177365.26        188099.18
# 2  ...        155897.42        166631.34        177365.26        188099.18
# 3  ...        155897.42        166631.34        177365.26        188099.18
# 4  ...        160268.37        171303.24        182338.11        193372.98
#
#    North-South_w17  North-South_w18  North-South_w19  North-South_w20  \
# 0        198833.10        209567.02        220300.94        231034.86
# 1        198833.10        209567.02        220300.94        231034.86
# 2        198833.10        209567.02        220300.94        231034.86
# 3        198833.10        209567.02        220300.94        231034.86
# 4        204407.85        215442.72        226477.59        237512.46
#
#    North-South_w21  North-South_w22
# 0       1089748.46       2163140.46
# 1       1089748.46       2163140.46
# 2       1089748.46       2163140.46
# 3       1089748.46       2163140.46
# 4       1120302.06       2223789.06
#
# [5 rows x 139 columns]

# %%
check_dataframe(std_rate_df)
# Out:
# <pandas.io.formats.style.Styler object at 0x7c508a14ef80>
# <style type="text/css">
# #T_76023_row0_col1, #T_76023_row0_col2, #T_76023_row1_col1, #T_76023_row1_col2, #T_76023_row2_col1, #T_76023_row2_col2, #T_76023_row3_col1, #T_76023_row3_col2, #T_76023_row4_col1, #T_76023_row4_col2, #T_76023_row5_col1, #T_76023_row5_col2, #T_76023_row6_col1, #T_76023_row6_col2, #T_76023_row7_col1, #T_76023_row7_col2, #T_76023_row8_col1, #T_76023_row8_col2, #T_76023_row9_col1, #T_76023_row9_col2, #T_76023_row10_col1, #T_76023_row10_col2, #T_76023_row11_col1, #T_76023_row11_col2, #T_76023_row12_col1, #T_76023_row12_col2, #T_76023_row13_col1, #T_76023_row13_col2, #T_76023_row14_col1, #T_76023_row14_col2, #T_76023_row15_col1, #T_76023_row15_col2, #T_76023_row16_col1, #T_76023_row16_col2, #T_76023_row17_col1, #T_76023_row17_col2, #T_76023_row18_col1, #T_76023_row18_col2, #T_76023_row19_col1, #T_76023_row19_col2, #T_76023_row20_col1, #T_76023_row20_col2, #T_76023_row21_col1, #T_76023_row21_col2, #T_76023_row22_col1, #T_76023_row22_col2, #T_76023_row23_col1, #T_76023_row23_col2, #T_76023_row24_col1, #T_76023_row24_col2, #T_76023_row25_col1, #T_76023_row25_col2, #T_76023_row26_col1, #T_76023_row26_col2, #T_76023_row27_col1, #T_76023_row27_col2, #T_76023_row28_col1, #T_76023_row28_col2, #T_76023_row29_col1, #T_76023_row29_col2, #T_76023_row30_col1, #T_76023_row30_col2, #T_76023_row31_col1, #T_76023_row31_col2, #T_76023_row32_col1, #T_76023_row32_col2, #T_76023_row33_col1, #T_76023_row33_col2, #T_76023_row34_col1, #T_76023_row34_col2, #T_76023_row35_col1, #T_76023_row35_col2, #T_76023_row36_col1, #T_76023_row36_col2, #T_76023_row37_col1, #T_76023_row37_col2, #T_76023_row38_col1, #T_76023_row38_col2, #T_76023_row39_col1, #T_76023_row39_col2, #T_76023_row40_col1, #T_76023_row40_col2, #T_76023_row41_col1, #T_76023_row41_col2, #T_76023_row42_col1, #T_76023_row42_col2, #T_76023_row43_col1, #T_76023_row43_col2, #T_76023_row44_col1, #T_76023_row44_col2, #T_76023_row45_col1, #T_76023_row45_col2, #T_76023_row46_col1, #T_76023_row46_col2, #T_76023_row47_col1, #T_76023_row47_col2, #T_76023_row48_col1, #T_76023_row48_col2, #T_76023_row49_col1, #T_76023_row49_col2, #T_76023_row50_col1, #T_76023_row50_col2, #T_76023_row51_col1, #T_76023_row51_col2, #T_76023_row52_col1, #T_76023_row52_col2, #T_76023_row53_col1, #T_76023_row53_col2, #T_76023_row54_col1, #T_76023_row54_col2, #T_76023_row55_col1, #T_76023_row55_col2, #T_76023_row56_col1, #T_76023_row56_col2, #T_76023_row57_col1, #T_76023_row57_col2, #T_76023_row58_col1, #T_76023_row58_col2, #T_76023_row59_col1, #T_76023_row59_col2, #T_76023_row60_col1, #T_76023_row60_col2, #T_76023_row61_col1, #T_76023_row61_col2, #T_76023_row62_col1, #T_76023_row62_col2, #T_76023_row63_col1, #T_76023_row63_col2, #T_76023_row64_col1, #T_76023_row64_col2, #T_76023_row65_col1, #T_76023_row65_col2, #T_76023_row66_col1, #T_76023_row66_col2, #T_76023_row67_col1, #T_76023_row67_col2, #T_76023_row68_col1, #T_76023_row68_col2, #T_76023_row69_col1, #T_76023_row69_col2, #T_76023_row70_col1, #T_76023_row70_col2, #T_76023_row71_col1, #T_76023_row71_col2, #T_76023_row72_col1, #T_76023_row72_col2, #T_76023_row73_col1, #T_76023_row73_col2, #T_76023_row74_col1, #T_76023_row74_col2, #T_76023_row75_col1, #T_76023_row75_col2, #T_76023_row76_col1, #T_76023_row76_col2, #T_76023_row77_col1, #T_76023_row77_col2, #T_76023_row78_col1, #T_76023_row78_col2, #T_76023_row79_col1, #T_76023_row79_col2, #T_76023_row80_col1, #T_76023_row80_col2, #T_76023_row81_col1, #T_76023_row81_col2, #T_76023_row82_col1, #T_76023_row82_col2, #T_76023_row83_col1, #T_76023_row83_col2, #T_76023_row84_col1, #T_76023_row84_col2, #T_76023_row85_col1, #T_76023_row85_col2, #T_76023_row86_col1, #T_76023_row86_col2, #T_76023_row87_col1, #T_76023_row87_col2, #T_76023_row88_col1, #T_76023_row88_col2, #T_76023_row89_col1, #T_76023_row89_col2, #T_76023_row90_col1, #T_76023_row90_col2, #T_76023_row91_col1, #T_76023_row91_col2, #T_76023_row92_col1, #T_76023_row92_col2, #T_76023_row93_col1, #T_76023_row93_col2, #T_76023_row94_col1, #T_76023_row94_col2, #T_76023_row95_col1, #T_76023_ ...
#   background-color: #8dd3c7;
#   color: #000000;
# }
# </style>
# <table id="T_76023" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76023_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_76023_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#       <th id="T_76023_level0_col2" class="col_heading level0 col2" >% Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76023_level0_row0" class="row_heading level0 row0" >Location</th>
#       <td id="T_76023_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_76023_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_76023_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_76023_level0_row1" class="row_heading level0 row1" >HN-HCM_w2</th>
#       <td id="T_76023_row1_col0" class="data row1 col0" >float64</td>
#       <td id="T_76023_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_76023_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_76023_level0_row2" class="row_heading level0 row2" >HNHCM-DN_w19</th>
#       <td id="T_76023_row2_col0" class="data row2 col0" >float64</td>
#       <td id="T_76023_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_76023_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_76023_level0_row3" class="row_heading level0 row3" >HNHCM-DN_w20</th>
#       <td id="T_76023_row3_col0" class="data row3 col0" >float64</td>
#       <td id="T_76023_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_76023_row3_col2" class="data row3 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_76023_level0_row4" class="row_heading level0 row4" >HNHCM-DN_w21</th>
#       <td id="T_76023_row4_col0" class="data row4 col0" >float64</td>
#       <td id="T_76023_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_76023_row4_col2" class="data row4 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_76023_level0_row5" class="row_heading level0 row5" >HNHCM-DN_w22</th>

# %%
exp_rate_df = pd.read_excel("/content/drive/MyDrive/Năm III/SCM/ROUND 2/data/ExpRate.xlsx", sheet_name='Sheet1')
exp_rate_df.head()
# Out:
#    Location  Intra city_w0  Intra city_w1  Intra city_w2  Intra city_w3  \
# 0   TPHCM 1          30000          30000          30000          30000
# 1   TPHCM 2          30000          30000          30000          30000
# 2   TPHCM 3          30000          30000          30000          30000
# 3   TPHCM 4          30000          30000          30000          30000
# 4  Ha Noi 1          30000          30000          30000          30000
#
#    Intra city_w4  Intra city_w5  Intra city_w6  Intra city_w7  Intra city_w8  \
# 0          30000          34000          34000          38000          38000
# 1          30000          34000          34000          38000          38000
# 2          30000          34000          34000          38000          38000
# 3          30000          34000          34000          38000          38000
# 4          30000          34000          34000          38000          38000
#
#    ...  North-South_w13  North-South_w14  North-South_w15  North-South_w16  \
# 0  ...            80000            80000            90000            90000
# 1  ...            80000            80000            90000            90000
# 2  ...            80000            80000            90000            90000
# 3  ...            80000            80000            90000            90000
# 4  ...            80000            80000            90000            90000
#
#    North-South_w17  North-South_w18  North-South_w19  North-South_w20  \
# 0           100000           100000           110000           110000
# 1           100000           100000           110000           110000
# 2           100000           100000           110000           110000
# 3           100000           100000           110000           110000
# 4           100000           100000           110000           110000
#
#    North-South_w21  North-South_w22
# 0           510000          1010000
# 1           510000          1010000
# 2           510000          1010000
# 3           510000          1010000
# 4           510000          1010000
#
# [5 rows x 139 columns]

# %%
check_dataframe(exp_rate_df)
# Out:
# <pandas.io.formats.style.Styler object at 0x7c508a0bc730>
# <style type="text/css">
# #T_64e89_row0_col1, #T_64e89_row0_col2, #T_64e89_row1_col1, #T_64e89_row1_col2, #T_64e89_row2_col1, #T_64e89_row2_col2, #T_64e89_row3_col1, #T_64e89_row3_col2, #T_64e89_row4_col1, #T_64e89_row4_col2, #T_64e89_row5_col1, #T_64e89_row5_col2, #T_64e89_row6_col1, #T_64e89_row6_col2, #T_64e89_row7_col1, #T_64e89_row7_col2, #T_64e89_row8_col1, #T_64e89_row8_col2, #T_64e89_row9_col1, #T_64e89_row9_col2, #T_64e89_row10_col1, #T_64e89_row10_col2, #T_64e89_row11_col1, #T_64e89_row11_col2, #T_64e89_row12_col1, #T_64e89_row12_col2, #T_64e89_row13_col1, #T_64e89_row13_col2, #T_64e89_row14_col1, #T_64e89_row14_col2, #T_64e89_row15_col1, #T_64e89_row15_col2, #T_64e89_row16_col1, #T_64e89_row16_col2, #T_64e89_row17_col1, #T_64e89_row17_col2, #T_64e89_row18_col1, #T_64e89_row18_col2, #T_64e89_row19_col1, #T_64e89_row19_col2, #T_64e89_row20_col1, #T_64e89_row20_col2, #T_64e89_row21_col1, #T_64e89_row21_col2, #T_64e89_row22_col1, #T_64e89_row22_col2, #T_64e89_row23_col1, #T_64e89_row23_col2, #T_64e89_row24_col1, #T_64e89_row24_col2, #T_64e89_row25_col1, #T_64e89_row25_col2, #T_64e89_row26_col1, #T_64e89_row26_col2, #T_64e89_row27_col1, #T_64e89_row27_col2, #T_64e89_row28_col1, #T_64e89_row28_col2, #T_64e89_row29_col1, #T_64e89_row29_col2, #T_64e89_row30_col1, #T_64e89_row30_col2, #T_64e89_row31_col1, #T_64e89_row31_col2, #T_64e89_row32_col1, #T_64e89_row32_col2, #T_64e89_row33_col1, #T_64e89_row33_col2, #T_64e89_row34_col1, #T_64e89_row34_col2, #T_64e89_row35_col1, #T_64e89_row35_col2, #T_64e89_row36_col1, #T_64e89_row36_col2, #T_64e89_row37_col1, #T_64e89_row37_col2, #T_64e89_row38_col1, #T_64e89_row38_col2, #T_64e89_row39_col1, #T_64e89_row39_col2, #T_64e89_row40_col1, #T_64e89_row40_col2, #T_64e89_row41_col1, #T_64e89_row41_col2, #T_64e89_row42_col1, #T_64e89_row42_col2, #T_64e89_row43_col1, #T_64e89_row43_col2, #T_64e89_row44_col1, #T_64e89_row44_col2, #T_64e89_row45_col1, #T_64e89_row45_col2, #T_64e89_row46_col1, #T_64e89_row46_col2, #T_64e89_row47_col1, #T_64e89_row47_col2, #T_64e89_row48_col1, #T_64e89_row48_col2, #T_64e89_row49_col1, #T_64e89_row49_col2, #T_64e89_row50_col1, #T_64e89_row50_col2, #T_64e89_row51_col1, #T_64e89_row51_col2, #T_64e89_row52_col1, #T_64e89_row52_col2, #T_64e89_row53_col1, #T_64e89_row53_col2, #T_64e89_row54_col1, #T_64e89_row54_col2, #T_64e89_row55_col1, #T_64e89_row55_col2, #T_64e89_row56_col1, #T_64e89_row56_col2, #T_64e89_row57_col1, #T_64e89_row57_col2, #T_64e89_row58_col1, #T_64e89_row58_col2, #T_64e89_row59_col1, #T_64e89_row59_col2, #T_64e89_row60_col1, #T_64e89_row60_col2, #T_64e89_row61_col1, #T_64e89_row61_col2, #T_64e89_row62_col1, #T_64e89_row62_col2, #T_64e89_row63_col1, #T_64e89_row63_col2, #T_64e89_row64_col1, #T_64e89_row64_col2, #T_64e89_row65_col1, #T_64e89_row65_col2, #T_64e89_row66_col1, #T_64e89_row66_col2, #T_64e89_row67_col1, #T_64e89_row67_col2, #T_64e89_row68_col1, #T_64e89_row68_col2, #T_64e89_row69_col1, #T_64e89_row69_col2, #T_64e89_row70_col1, #T_64e89_row70_col2, #T_64e89_row71_col1, #T_64e89_row71_col2, #T_64e89_row72_col1, #T_64e89_row72_col2, #T_64e89_row73_col1, #T_64e89_row73_col2, #T_64e89_row74_col1, #T_64e89_row74_col2, #T_64e89_row75_col1, #T_64e89_row75_col2, #T_64e89_row76_col1, #T_64e89_row76_col2, #T_64e89_row77_col1, #T_64e89_row77_col2, #T_64e89_row78_col1, #T_64e89_row78_col2, #T_64e89_row79_col1, #T_64e89_row79_col2, #T_64e89_row80_col1, #T_64e89_row80_col2, #T_64e89_row81_col1, #T_64e89_row81_col2, #T_64e89_row82_col1, #T_64e89_row82_col2, #T_64e89_row83_col1, #T_64e89_row83_col2, #T_64e89_row84_col1, #T_64e89_row84_col2, #T_64e89_row85_col1, #T_64e89_row85_col2, #T_64e89_row86_col1, #T_64e89_row86_col2, #T_64e89_row87_col1, #T_64e89_row87_col2, #T_64e89_row88_col1, #T_64e89_row88_col2, #T_64e89_row89_col1, #T_64e89_row89_col2, #T_64e89_row90_col1, #T_64e89_row90_col2, #T_64e89_row91_col1, #T_64e89_row91_col2, #T_64e89_row92_col1, #T_64e89_row92_col2, #T_64e89_row93_col1, #T_64e89_row93_col2, #T_64e89_row94_col1, #T_64e89_row94_col2, #T_64e89_row95_col1, #T_64e89_ ...
#   background-color: #8dd3c7;
#   color: #000000;
# }
# </style>
# <table id="T_64e89" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64e89_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_64e89_level0_col1" class="col_heading level0 col1" >Missing Values</th>
#       <th id="T_64e89_level0_col2" class="col_heading level0 col2" >% Missing Values</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64e89_level0_row0" class="row_heading level0 row0" >Location</th>
#       <td id="T_64e89_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_64e89_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_64e89_row0_col2" class="data row0 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_64e89_level0_row1" class="row_heading level0 row1" >HN-HCM_w2</th>
#       <td id="T_64e89_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_64e89_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_64e89_row1_col2" class="data row1 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_64e89_level0_row2" class="row_heading level0 row2" >HNHCM-DN_w19</th>
#       <td id="T_64e89_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_64e89_row2_col1" class="data row2 col1" >0</td>
#       <td id="T_64e89_row2_col2" class="data row2 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_64e89_level0_row3" class="row_heading level0 row3" >HNHCM-DN_w20</th>
#       <td id="T_64e89_row3_col0" class="data row3 col0" >int64</td>
#       <td id="T_64e89_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_64e89_row3_col2" class="data row3 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_64e89_level0_row4" class="row_heading level0 row4" >HNHCM-DN_w21</th>
#       <td id="T_64e89_row4_col0" class="data row4 col0" >int64</td>
#       <td id="T_64e89_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_64e89_row4_col2" class="data row4 col2" >0.00%</td>
#     </tr>
#     <tr>
#       <th id="T_64e89_level0_row5" class="row_heading level0 row5" >HNHCM-DN_w22</th>
#       <td id=

# %% [markdown]
# ## **Mathematical model**

# %% [markdown]
# With $I$ as the collective of n potetial facilities, $J$ as the collective of n customers. The theoretical mathematical model for the facility location problem with single sourcing is described as below [(Holmberg, Rönnqvist & Yuan, 1999)](https://doi.org/10.1016/S0377-2217(98)00008-3):
#
# Parameters:
#
# $f_i$ is the fixed cost of using/opening facility i.
#
# $c_{ij}$ is the variable cost of assigning customer j to facility i.
#
# $b_i$ is the capacity of facility i.
#
# $d_j$ is the demand of customer j.
#
# Decision variables:
#
# $y_i=1$ if facility i opens, 0 otherwise.
#
# $x_{ij}=1$ if facility i serves customer j, 0 otherwise.
#
# The objective function is to minimize the cost of assigning customers to open facilities and the cost of establishing such facilities.
#
# Objective function:
#
# $v^* = \sum_{i=1}^{n} y_i\cdot f_i + \sum_{i=1}^{n} \sum_{j=1}^{m} c_{ij}\cdot x_{ij}$
#
# Constraints:
#
# (1) Customer demand served by a certain facility does not exceed its capacity
#
# $\sum_{j=1}^{m}d_j\cdot x_{ij} \leq b_i\cdot y_i$
#
# (2) A customer is served by a single source
#
# $\sum_{i=1}^{n}x_{ij} = 1$

# %% [markdown]
# Based on the theoretical model, I added three constraints:
#
# (3) Only 10 fulfillment centers will be opened at max
#
# (4) Each subregion has at least 1 fulfillment center

# %% [markdown]
# With $ I $ as the collective of n potetial locations for fulfillment centers, $ J $ as the collective of n customers groups, $ R $ is the collective of region, $ IR_r $ is the collective of potential location in region $ r$, $ T $ is the collective of subregions, and $ SR_t $ is the collective of potential locations for fulfillment centers in subregion $ t$. The modified mathematical model is described as below:
#
# Parameters:
#
# $f_i$ is the cost of using facility i in one year.
#
# $c_{ij}$ is the shipping cost from fulfillment center i to customer j per one unit.
#
# $l_{ij}$ is the lead time from fulfillment center i to customer j per one unit.
#
# $d_j$ is the demand of customer j in one year.
#
# $b_i$ is the capacity of fulfillment center i in one year.
#
# Decision variables:
#
# $y_i=1$ if fulfillment center i opens, 0 otherwise.
#
# $x_{ij}=1$ if fulfillment center i serves customer (group) j, 0 otherwise.
#
# Considering the long-term effect, I do not include the fixed cost of opening the fulfillment center into the model. The objective function is to minimize the total effect of operational cost & shipping cost to serve all the demand in one year.
#
# Objective function:
#
# $v^* = \sum_{i=1}^{n} y_i\cdot f_i + \sum_{i=1}^{n} \sum_{j=1}^{m} d_j\cdot c_{ij}\cdot x_{ij}$
#
# Constraints:
#
# (1) Customer demand served by a certain facility does not exceed its capacity
#
# $\sum_{j=1}^{m}d_j\cdot x_{ij} \leq b_i\cdot y_i \text{ } \forall i \in I$
#
# (2) A customer is served by a single source
#
# $\sum_{i=1}^{n}x_{ij} = 1 \text{ } \forall j \in J$
#
# (3) Only 10 fulfillment centers will be opened at max
#
# $\sum_{i=1}^{n} y_i \leq 10$
#
# (4) Each subregion has at least 1 fulfillment center
#
# $\sum_{i \in SR_t} y_i \geq 1 \text{ } \forall t \in T$

# %% [markdown]
# ## **Input Preparation**

# %%
# Generate fulfillment centers' capacity dictionary
def fcs_capacity_generate(fcs, fixed_cap):
  result = {}
  for fc in fcs:
    result[fc] = fixed_cap
  return result

# Generate customers' demand dictionary
def customer_demand_generate(customers, cus_df):
  result = {}
  for customer in customers:
    result[customer] = cus_df[cus_df['Customer Group'] == customer]['Demand 2024'].values[0]
  return result

# Generate fulfillment centers' operational cost
def fcs_operational_cost_generate(fcs, annual_operational_cost):
  result = {}
  for fc in fcs:
    result[fc] = annual_operational_cost
  return result

# Retrieve shipping type
def shipping_type(fc, customer, fcs_df, cus_df):
  # HCM - HN special cases
  #print('Start comparing HCM & HN')
  if (customer[:-2]=='TPHCM') or (customer[:-2]=='Ha Noi'):
    # If fc and customer are both HCM or are both HN
    if (fc[:-2] == customer[:-2]):
      return "Intra city"
    if (fc[:-2] == "Ha Noi") or (fc[:-2] == "TPHCM"):
      return "HN-HCM"
    if (fc == "Da Nang"):
      return "HNHCM-DN"
  # Da Nang special cases
  #print('Start Da Nang')
  if (customer == 'Da Nang'):
    if (fc[:-2] == 'Ha Noi') or (fc[:-2] == 'TPHCM'):
      return "HNHCM-DN"
  # Other cases
  #print('Start Intra City')
  if (customer == fc):
      return "Intra city"
  #print('Start Intra region')
  if (fcs_df[fcs_df['Location'] == fc]['Region'].values[0] == cus_df[cus_df['Customer Group'] == customer]['Region'].values[0]):
      return "Intra region"
  #print('Start North-South')
  if (fcs_df[fcs_df['Location'] == fc]['Region'].values[0] == 'North') and (cus_df[cus_df['Customer Group'] == customer]['Region'].values[0] == 'South'):
      return "North-South"
  if (fcs_df[fcs_df['Location'] == fc]['Region'].values[0] == 'South') and (cus_df[cus_df['Customer Group'] == customer]['Region'].values[0] == 'North'):
      return "North-South"
  #print('Start NorthSouth-Mid')
  if (fcs_df[fcs_df['Location'] == fc]['Region'].values[0] == 'North') and (cus_df[cus_df['Customer Group'] == customer]['Region'].values[0] == 'Central'):
      return "NorthSouth-Mid"
  if (fcs_df[fcs_df['Location'] == fc]['Region'].values[0] == 'South') and (cus_df[cus_df['Customer Group'] == customer]['Region'].values[0] == 'Central'):
      return "NorthSouth-Mid"
  if (fcs_df[fcs_df['Location'] == fc]['Region'].values[0] == 'Central') and (cus_df[cus_df['Customer Group'] == customer]['Region'].values[0] == 'North'):
      return "NorthSouth-Mid"
  if (fcs_df[fcs_df['Location'] == fc]['Region'].values[0] == 'Central') and (cus_df[cus_df['Customer Group'] == customer]['Region'].values[0] == 'South'):
      return "NorthSouth-Mid"

# Retrieve weight distribution
def weight_type(type, distribution_df):
  return distribution_df[distribution_df['Encoded Weight'] == type]['% Distribution rate'].values[0]

# Retrieve shipping cost
# 80% demand is for standard, 20% demand is for express
def total_shipping_cost_for_one_cusgroup(fc, customer, fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df):
  factor_std = 0
  factor_exp = 0
  result = 0
  demand = cus_df[cus_df['Customer Group'] == customer]['Demand 2024'].values[0]
  for weight in weight_list:
    factor_std = factor_std + weight_type(weight, std_demand_df) * std_rate_df[std_rate_df['Location']==customer][shipping_type(fc, customer, fcs_df, cus_df)+"_"+weight].values[0]
  result = demand*0.8*factor_std
  for weight in weight_list:
    factor_exp = factor_exp + weight_type(weight, exp_demand_df) * exp_rate_df[exp_rate_df['Location']==customer][shipping_type(fc, customer, fcs_df, cus_df)+"_"+weight].values[0]
  result = result + demand*0.2*factor_exp
  return result

def average_shipping_cost_on_one_unit(fc, customer, fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df):
  factor_std = 0
  factor_exp = 0
  result = 0
  #print("Demand:", demand)
  for weight in weight_list:
    #print("Weight:", weight)
    #print('Rate:', std_rate_df[std_rate_df['Location']==customer][shipping_type(fc, customer, fcs_df, cus_df)+"_"+weight])
    factor_std = factor_std + weight_type(weight, std_demand_df) * std_rate_df[std_rate_df['Location']==customer][shipping_type(fc, customer, fcs_df, cus_df)+"_"+weight].values[0]
    #print("Factor standard:", factor_std)
  result = 0.8*factor_std
  for weight in weight_list:
    factor_exp = factor_exp + weight_type(weight, exp_demand_df) * exp_rate_df[exp_rate_df['Location']==customer][shipping_type(fc, customer, fcs_df, cus_df)+"_"+weight].values[0]
  result = result+0.2*factor_exp
  return result

# Generate shipping cost dictionary
def shipping_cost_generate(fcs, customers, fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df):
  result = {}
  for fc in fcs:
    for customer in customers:
      #print("FC:", fc)
      #print("Customer:", customer)
      result[(fc, customer)] = average_shipping_cost_on_one_unit(fc, customer, fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df)
  return result

# Generate subregion dictionary
def subregion_generate(fcs_df, subregions):
  result = {}
  for sub in subregions:
    result[sub] = list(fcs_df[fcs_df['Subregion'] == sub]['Location'].values)
  return result


# Retrieve average shipping cost for result
def average_shipping_result(assignFC, customers, customer_demand, fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df):
  i = 0
  total_demand = 0
  result = 0
  while i < len(customers):
    ship_cost = total_shipping_cost_for_one_cusgroup(assignFC[i], customers[i], fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df)
    total_demand = total_demand + customer_demand[customers[i]]
    result = result + ship_cost
    i = i + 1
  result = result/total_demand
  return result

# Retrieve exact total operational and shipping cost
def total_operation_shipping_cost(assignFC, customers, chosen_FCs_df, customer_demand, fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df):
  i = 0
  result = 0
  # Shipping cost
  while i < len(customers):
    ship_cost = total_shipping_cost_for_one_cusgroup(assignFC[i], customers[i], fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df)
    result = result + ship_cost
    i = i + 1
  # Operational cost, demand assignd > 80000 -> 762000000, demand assigned <= 80000 -> 450000000
  result = result + sum(chosen_FCs_df[chosen_FCs_df["Demand assigned"] > 80000]["Open"]*762000000) + sum(chosen_FCs_df[chosen_FCs_df["Demand assigned"] <= 80000]["Open"]*450000000)
  return result

# %%
# Retrieve input
fcs = list(fcs_df['Location'])
customers = list(cus_df['Customer Group'])
fcs_capacity = fcs_capacity_generate(fcs, 250000)
customer_demand = customer_demand_generate(customers, cus_df)
fcs_operational_cost = fcs_operational_cost_generate(fcs, 606000000)
shipping_cost = shipping_cost_generate(fcs, customers, fcs_df, cus_df, weight_list, std_demand_df, exp_demand_df, std_rate_df, exp_rate_df)

# %% [markdown]
# ## **Optimal Fulfillment Centers With Subregion Constraint (4)**

# %%
subregion_dict = subregion_generate(fcs_df, subregions)

# %%
# Create a new Gurobi model
model = gp.Model()

# Decision Variables
yi = model.addVars(fcs, vtype=GRB.BINARY, name="yi")  # Fulfillment center opens
xij = model.addVars(fcs, customers, vtype=GRB.BINARY, name="xij")  # Fulfillment center serves customer group j

# Objective Function
model.setObjective(
    gp.quicksum(yi[i] * fcs_operational_cost[i] for i in fcs) +
    gp.quicksum(customer_demand[j] * shipping_cost[i, j] * xij[i, j] for i in fcs for j in customers),
    sense=GRB.MINIMIZE
)

# Constraints
for i in fcs:
    model.addConstr(
        gp.quicksum(customer_demand[j] * xij[i, j] for j in customers) <= fcs_capacity[i] * yi[i],
        name=f"capacity_constraint_{i}"
    )

for j in customers:
    model.addConstr(
        gp.quicksum(xij[i, j] for i in fcs) == 1,
        name=f"single_source_constraint_{j}"
    )

model.addConstr(
    gp.quicksum(yi[i] for i in fcs) <= 10,
    name="max_fulfillments_constraint"
)

for t in subregions:
    model.addConstr(
        gp.quicksum(yi[i] for i in subregion_dict[t]) >= 1,
        name=f"subregion_constraint_{t}"
    )

# Solve the optimization problem
model.optimize()

# Print solution
if model.status == GRB.OPTIMAL:
    openFC = []
    demandAssigned = []
    print("Optimal solution found.")
    for i in fcs:
      demand = 0
      if (yi[i].x == 1):
        openFC.append(1)
        print(f"Open Fulfillment Center FC {i}")
        for j in customers:
          if xij[i, j].x == 1:
            demand = demand + customer_demand[j]
      else:
        openFC.append(0)
      demandAssigned.append(demand)
    assignFC = []
    for j in customers:
      for i in fcs:
        if (xij[i, j].x == 1):
          assignFC.append(i)
          print(f"Customer Cus {j} is assigned to fulfillment centers {i}")
else:
    print("No optimal solution found.")
# Out:
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (linux64 - "Ubuntu 22.04.3 LTS")
#
# CPU model: Intel(R) Xeon(R) CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 1 physical cores, 2 logical processors, using up to 2 threads
#
# Optimize a model with 100 rows, 1953 columns and 3937 nonzeros
# Model fingerprint: 0x46463344
# Variable types: 0 continuous, 1953 integer (1953 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+05]
#   Objective range  [1e+07, 1e+10]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+01]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 5.967656e+10
# Presolve removed 1 rows and 1 columns
# Presolve time: 0.03s
# Presolved: 99 rows, 1952 columns, 3934 nonzeros
# Variable types: 0 continuous, 1952 integer (1952 binary)
# Found heuristic solution: objective 5.821958e+10
#
# Root relaxation: objective 4.101206e+10, 112 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 4.1012e+10    0   32 5.8220e+10 4.1012e+10  29.6%     -    0s
# H    0     0                    4.409242e+10 4.1012e+10  6.99%     -    0s
#      0     0 4.2854e+10    0    6 4.4092e+10 4.2854e+10  2.81%     -    0s
# H    0     0                    4.288237e+10 4.2854e+10  0.07%     -    0s
#      0     0 4.2854e+10    0    3 4.2882e+10 4.2854e+10  0.07%     -    0s
#      0     0 4.2854e+10    0    7 4.2882e+10 4.2854e+10  0.07%     -    0s
#      0     0 4.2854e+10    0    7 4.2882e+10 4.2854e+10  0.07%     -    0s
#      0     0 4.2854e+10    0    5 4.2882e+10 4.2854e+10  0.07%     -    0s
#      0     0     cutoff    0      4.2882e+10 4.2882e+10  0.00%     -    0s
#
# Cutting planes:
#   Gomory: 3
#   Cover: 10
#   Clique: 2
#   MIR: 3
#   StrongCG: 3
#
# Explored 1 nodes (516 simplex iterations) in 0.16 seconds (0.03 work units)
# Thread count was 2 (of 2 available processors)
#
# Solution count 5: 4.28824e+10 4.28824e+10 4.40924e+10 ... 5.96766e+10
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.288237087460e+10, best bound 4.288237087460e+10, gap 0.0000%
# Optimal solution found.
# Open Fulfillment Center FC TPHCM 1
# Open Fulfillment Center FC TPHCM 2
# Open Fulfillment Center FC TPHCM 3
# Open Fulfillment Center FC Ha Noi 1
# Open Fulfillment Center FC Ha Noi 2
# Open Fulfillment Center FC Can Tho
# Open Fulfillment Center FC Da Nang
# Open Fulfillment Center FC Lao Cai
# Open Fulfillment Center FC Thanh Hoa
# Customer Cus TPHCM 1 is assigned to fulfillment centers Can Tho
# Customer Cus TPHCM 2 is assigned to fulfillment centers TPHCM 3
# Customer Cus TPHCM 3 is assigned to fulfillment centers TPHCM 2
# Customer Cus TPHCM 4 is assigned to fulfillment centers TPHCM 1
# Customer Cus Ha Noi 1 is assigned to fulfillment centers Ha Noi 2
# Customer Cus Ha Noi 2 is assigned to fulfillment centers Ha Noi 1
# Customer Cus An Giang is assigned to fulfillment centers TPHCM 2
# Customer Cus Ba Ria - Vung Tau is assigned to fulfillment centers TPHCM 1
# Customer Cus Bac Giang is assigned to fulfillment centers Ha Noi 1
# Customer Cus Bac Kan is assigned to fulfillment centers Ha Noi 1
# Customer Cus Bac Lieu is assigned to fulfillment centers TPHCM 2
# Customer Cus Bac Ninh is assigned to fulfillment centers Ha Noi 1
# Customer Cus Ben Tre is assigned to fulfillment centers TPHCM 2
# Customer Cus Binh Dinh is assigned to fulfillment centers Da Nang
# Customer Cus Binh Duong is assigned to fulfillment centers TPHCM 1
# Customer Cus Binh Phuoc is assigned to fulfillment centers TPHCM 2
# Customer Cus Binh Thuan is assigned to fulfillment centers Da Nang
# Customer Cus Ca Mau is assigned to fulfillment centers TPHCM 2
# Customer Cus Can Tho is assigned to fulfillment centers Can Tho
# Customer Cus Da Nang is assigned to fulfillment centers Da Nang
# Customer Cus Dak Lak is assigned to fulfillment centers Thanh Hoa
# Customer Cus Dak Nong is assigned to fulfillment centers Da Nang
# Customer Cus Dong Nai is assigned to fulfillment centers TPHCM 1
# Customer Cus Dong Thap is assigned to fulfillment centers TPHCM 1
# Customer Cus Gia Lai is assigned to fulfillment centers Da Nang
# Customer Cus Ha Nam is assigned to fulfillment centers Ha Noi 1
# Customer Cus Ha Tinh is assigned to fulfillment centers Da Nang
# Customer Cus Hai Duong is assigned to fulfillment centers Lao Cai
# Customer Cus Hai Phong is assigned to fulfillment centers Ha Noi 1
# Customer Cus Hau Giang is assigned to fulfillment centers TPHCM 2
# Customer Cus Hoa Binh is assigned to fulfillment centers Ha Noi 1
# Customer Cus Hung Yen is assigned to fulfillment centers Ha Noi 1
# Customer Cus Khanh Hoa is assigned to fulfillment centers Thanh Hoa
# Customer Cus Kien Giang is assigned to fulfillment centers TPHCM 2
# Customer Cus Kon Tum is assigned to fulfillment centers Da Nang
# Customer Cus Lam Dong is assigned to fulfillment centers Thanh Hoa
# Customer Cus Lang Son is assigned to fulfillment centers Lao Cai
# Customer Cus Lao Cai is assigned to fulfillment centers Lao Cai
# Customer Cus Long An is assigned to fulfillment centers TPHCM 2
# Customer Cus Nam Dinh is assigned to fulfillment centers Lao Cai
# Customer Cus Nghe An is assigned to fulfillment centers Thanh Hoa
# Customer Cus Ninh Binh is assigned to fulfillment centers Ha Noi 1
# Customer Cus Ninh Thuan is assigned to fulfillment centers Da Nang
# Customer Cus Phu Tho is assigned to fulfillment centers Ha Noi 1
# Customer Cus Phu Yen is assigned to fulfillment centers Da Nang
# Customer Cus Quang Binh is assigned to fulfillment centers Da Nang
# Customer Cus Quang Nam is assigned to fulfillment centers Thanh Hoa
# Customer Cus Quang Ngai is assigned to fulfillment centers Da Nang
# Customer Cus Quang Ninh is assigned to fulfillment centers Lao Cai
# Customer Cus Quang Tri is assigned to fulfillment centers Da Nang
# Customer Cus Soc Trang is assigned to fulfillment centers TPHCM 2
# Customer Cus Tay Ninh is assigned to fulfillment centers TPHCM 2
# Customer Cus Thai Binh is assigned to fulfillment centers Ha Noi 1
# Customer Cus Thai Nguyen is assigned to fulfillment centers Ha Noi 1
# Customer Cus Thanh Hoa is assigned to fulfillment centers Thanh Hoa
# Customer Cus Thua Thien Hue is assigned to fulfillment centers Da Nang
# Customer Cus Tien Giang is assigned to fulfillment centers TPHCM 2
# Customer Cus Tra Vinh is assigned to fulfillment centers TPHCM 2
# Customer Cus Tuyen Quang is assigned to fulfillment centers Lao Cai
# Customer Cus Vinh Long is assigned to fulfillment centers TPHCM 2
# Customer Cus Vinh Phuc is assigned to fulfillment centers Ha Noi 1
# Customer Cus Yen Bai is assigned to fulfillment centers Ha Noi 1

# %%
chosen_FCs_df = pd.DataFrame({"FCs": fcs, "Open": openFC, "Demand assigned": demandAssigned})
chosen_FCs_df.to_excel('FCs With Subregion Constraint.xlsx', index=False)
files.download('FCs With Subregion Constraint.xlsx')

# %%
customer_assigned_df = pd.DataFrame({"Customer Groups": customers, "Assigned to": assignFC})
customer_assigned_df.to_excel('Customer Assigned With Subregion Constraint.xlsx', index=False)
files.download('Customer Assigned With Subregion Constraint.xlsx')
